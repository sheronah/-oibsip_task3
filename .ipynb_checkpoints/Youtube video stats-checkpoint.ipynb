# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Sheronah baBy\datasets\archive (4)\CAvideos.csv")
df
# Out:
#           video_id trending_date  \
# 0      n1WpP7iowLc      17.14.11
# 1      0dBIkQ4Mz1M      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      d380meD0W0M      17.14.11
# 4      2Vv-BfVoq4g      17.14.11
# ...            ...           ...
# 40876  sGolxsMSGfQ      18.14.06
# 40877  8HNuRNi8t70      18.14.06
# 40878  GWlKEM3m2EE      18.14.06
# 40879  lbMKLzQ4cNQ      18.14.06
# 40880  POTgw38-m58      18.14.06
#
#                                                    title     channel_title  \
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé        EminemVEVO
# 1                          PLUSH - Bad Unboxing Fan Mail         iDubbbzTV
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...      Rudy Mancuso
# 3                               I Dare You: GOING BALD!?          nigahiga
# 4            Ed Sheeran - Perfect (Official Music Video)        Ed Sheeran
# ...                                                  ...               ...
# ...

# %%
df.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40881 entries, 0 to 40880
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40881 non-null  object
#  1   trending_date           40881 non-null  object
#  2   title                   40881 non-null  object
#  3   channel_title           40881 non-null  object
#  4   category_id             40881 non-null  int64
#  5   publish_time            40881 non-null  object
#  6   tags                    40881 non-null  object
#  7   views                   40881 non-null  int64
#  8   likes                   40881 non-null  int64
#  9   dislikes                40881 non-null  int64
#  10  comment_count           40881 non-null  int64
#  11  thumbnail_link          40881 non-null  object
#  12  comments_disabled       40881 non-null  bool
#  13  ratings_disabled        40881 non-null  bool
# ...

# %%
df.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  40881.000000  4.088100e+04  4.088100e+04  4.088100e+04   4.088100e+04
# mean      20.795553  1.147036e+06  3.958269e+04  2.009195e+03   5.042975e+03
# std        6.775054  3.390913e+06  1.326895e+05  1.900837e+04   2.157902e+04
# min        1.000000  7.330000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       20.000000  1.439020e+05  2.191000e+03  9.900000e+01   4.170000e+02
# 50%       24.000000  3.712040e+05  8.780000e+03  3.030000e+02   1.301000e+03
# 75%       24.000000  9.633020e+05  2.871700e+04  9.500000e+02   3.713000e+03
# max       43.000000  1.378431e+08  5.053338e+06  1.602383e+06   1.114800e+06

# %%
# Check missing values percentage
missing_percent = df.isna().sum() / len(df) * 100
print("Missing values percentage:\n", missing_percent)
# Out:
# Missing values percentage:
#  video_id                  0.000000
# trending_date             0.000000
# title                     0.000000
# channel_title             0.000000
# category_id               0.000000
# publish_time              0.000000
# tags                      0.000000
# views                     0.000000
# likes                     0.000000
# dislikes                  0.000000
# comment_count             0.000000
# thumbnail_link            0.000000
# comments_disabled         0.000000
# ratings_disabled          0.000000
# video_error_or_removed    0.000000
# description               3.170177
# dtype: float64

# %%
# Handle missing values
df.fillna({'description': 'No description'}, inplace=True)

# %%
# Clean title and channel names
text_cols = ['title', 'channel_title', 'description', 'tags']
for col in text_cols:
    df[col] = df[col].str.strip()  # Remove whitespace
    df[col] = df[col].str.replace(r'\s+', ' ', regex=True)  # Replace multiple spaces

# %%
# Clean tags (convert to list and standardize format)
df['tags'] = df['tags'].str.replace('"', '').str.split('|')

# %%
# Extract useful features from publish_time
df['publish_time'] = pd.to_datetime(df['publish_time'])
df['publish_year'] = df['publish_time'].dt.year
df['publish_month'] = df['publish_time'].dt.month
df['publish_day'] = df['publish_time'].dt.day
df['publish_hour'] = df['publish_time'].dt.hour

# %%
# Check for duplicate videos
print("Duplicate video_ids:", df.duplicated(subset=['video_id']).sum())
# Out:
# Duplicate video_ids: 16454

# %%
# Remove exact duplicates
df.drop_duplicates(subset=['video_id'], keep='first', inplace=True)

# %%
# Check for near-duplicates (same title and channel)
near_dups = df.duplicated(subset=['title', 'channel_title'], keep=False)
if near_dups.sum() > 0:
    print(f"Found {near_dups.sum()} potential near-duplicates")
    # Option: Keep the most viewed version
    df.sort_values('views', ascending=False, inplace=True)
    df.drop_duplicates(subset=['title', 'channel_title'], keep='first', inplace=True)
# Out:
# Found 99 potential near-duplicates

# %%
# Convert boolean-like columns to proper booleans
bool_cols = ['comments_disabled', 'ratings_disabled', 'video_error_or_removed']
for col in bool_cols:
    df[col] = df[col].astype(bool)

# %%
# Standardize numerical columns (remove any commas, convert to numeric)
num_cols = ['views', 'likes', 'dislikes', 'comment_count']
for col in num_cols:
    if df[col].dtype == 'object':
        df[col] = df[col].str.replace(',', '').astype(float)

# %%
# Visualize numerical columns for outliers
plt.figure(figsize=(12, 6))
sns.boxplot(data=df[num_cols])
plt.yscale('log')  # Using log scale due to large ranges
plt.title("Boxplot of Numerical Columns (log scale)")
plt.xticks(rotation=45)
plt.show()

# %%
# Function to cap outliers
def cap_outliers(series, lower_quantile=0.01, upper_quantile=0.99):
    lower = series.quantile(lower_quantile)
    upper = series.quantile(upper_quantile)
    return series.clip(lower, upper)

# Cap outliers in engagement metrics
for col in num_cols:
    df[col] = cap_outliers(df[col])

# %%
# Create engagement metrics
df['like_ratio'] = df['likes'] / (df['likes'] + df['dislikes']).replace(0, 1)
df['comment_ratio'] = df['comment_count'] / df['views'].replace(0, 1)
df['engagement_rate'] = (df['likes'] + df['dislikes'] + df['comment_count']) / df['views'].replace(0, 1)

# %%
df['publish_time'] = pd.to_datetime(df['publish_time']) 
today = pd.Timestamp.now(tz='UTC')  
df['video_age_days'] = (today - df['publish_time']).dt.days

# %%
df['tag_count'] = df['tags'].apply(len)

# %%
print("\n=== Final Data Quality Report ===")
print("Shape:", df.shape)
# Out:
# === Final Data Quality Report ===
# Shape: (24367, 25)

# %%
print("\nMissing values:\n", df.isna().sum())
# Out:
# Missing values:
#  video_id                  0
# trending_date             0
# title                     0
# channel_title             0
# category_id               0
# publish_time              0
# tags                      0
# views                     0
# likes                     0
# dislikes                  0
# comment_count             0
# thumbnail_link            0
# comments_disabled         0
# ratings_disabled          0
# video_error_or_removed    0
# description               0
# publish_year              0
# publish_month             0
# publish_day               0
# publish_hour              0
# like_ratio                0
# comment_ratio             0
# engagement_rate           0
# video_age_days            0
# tag_count                 0
# dtype: int64

# %%
print("\nData types:\n", df.dtypes)
# Out:
# Data types:
#  video_id                               object
# trending_date                          object
# title                                  object
# channel_title                          object
# category_id                             int64
# publish_time              datetime64[ns, UTC]
# tags                                   object
# views                                 float64
# likes                                 float64
# dislikes                              float64
# comment_count                         float64
# thumbnail_link                         object
# comments_disabled                        bool
# ratings_disabled                         bool
# video_error_or_removed                   bool
# description                            object
# publish_year                            int32
# publish_month                           int32
# publish_day                             int32
# publish_hour                            int32
# ...
